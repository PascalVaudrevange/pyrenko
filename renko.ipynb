# %%
# %matplotlib notebook 
import sys
sys.path.append('.')

import matplotlib.pyplot as plt
import pandas as pd
import pyrenko

# %%
df = 1.e4 * pyrenko.renko.get_data(r=0.05, sigma=0.1)

# %%
plt.figure()
plt.plot(df)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
r = pyrenko.get_renko(df, delta=50)

# %%
plt.figure()
#plt.plot((r['binned_values'] - 5) * 50 + df[0], 's')
plt.plot(r['renko'] , 's')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
df
# Out:
# array([9973.89952998, 9972.79760465, 9962.14085883, ..., 9029.18446472,
#        9051.97116126, 9056.82810523])
